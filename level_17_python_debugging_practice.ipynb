# %% [markdown]
# # Level 17: Python Debugging Practice
#
# Debugging means finding and fixing mistakes in code.
#
# Programming errors are normal. The skill is learning how to read the error message and correct the problem.

# %% [markdown]
# ## 1. Name errors
#
# A name error happens when Python does not know a variable name.

# %%
gene_name = "TP53"
gene_name

# %% [markdown]
# Try changing `gene_name` to a wrong spelling and run the cell. Then fix it.

# %% [markdown]
# ## 2. Type errors
#
# A type error can happen when Python receives the wrong kind of value.

# %%
read_count = "100"
read_count_number = int(read_count)
read_count_number + 50

# %% [markdown]
# ## 3. Index errors
#
# An index error happens when you ask for a list item that does not exist.

# %%
genes = ["TP53", "BRCA1", "EGFR"]
genes[2]

# %% [markdown]
# ## 4. Check your assumptions with print

# %%
sequence = "ATGCGT"
print("Sequence:", sequence)
print("Length:", len(sequence))
print("GC count:", sequence.count("G") + sequence.count("C"))

# %% [markdown]
# ## 5. A small function to inspect

# %%
def gc_percent(sequence):
    gc_count = sequence.count("G") + sequence.count("C")
    return gc_count / len(sequence) * 100

gc_percent("ATGCGT")

# %% [markdown]
# ## Practice tasks
#
# Fix these common problems:
#
# 1. `gene = TP53` should store the text `TP53`.
# 2. `reads = "200"`; add 100 to it as a number.
# 3. `samples = ["S01", "S02"]`; display the second sample.
# 4. Write a `gc_percent` function and test it with two sequences.
# 5. Add print statements to show the sequence length and GC count before returning the percentage.

# %%
# Write your answers here
